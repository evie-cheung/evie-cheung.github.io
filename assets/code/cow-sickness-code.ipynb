# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container {width:100% !important; }</style>"))
# Out:
# <style>.container {width:100% !important; }</style>

# %%
# Create analysis environment, install libraries and import packages
# !pip install pmdarima
# !pip install missingno

# Python gets the webpages
import requests
from urllib.request import urlopen
# Creates structured, searchable object
from bs4 import BeautifulSoup  
import os
import math as m
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import json
from datetime import datetime
import datetime as dt
import sys
import seaborn as sns
from bokeh.plotting import figure, show, output_notebook
output_notebook()
from bokeh.layouts import gridplot
# Ignore unnecessary warnings
import warnings
warnings.filterwarnings("ignore")
from scipy.stats import pearsonr
import pmdarima as pmd
from statsmodels.tsa.arima.model import ARIMA
import missingno as msno

# %matplotlib inline
# Out:
# Requirement already satisfied: pmdarima in c:\users\jiexi\anaconda3\lib\site-packages (1.8.5)
# Requirement already satisfied: Cython!=0.29.18,>=0.29 in c:\users\jiexi\anaconda3\lib\site-packages (from pmdarima) (0.29.24)
# Requirement already satisfied: pandas>=0.19 in c:\users\jiexi\anaconda3\lib\site-packages (from pmdarima) (1.3.4)
# Requirement already satisfied: statsmodels!=0.12.0,>=0.11 in c:\users\jiexi\anaconda3\lib\site-packages (from pmdarima) (0.12.2)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in c:\users\jiexi\anaconda3\lib\site-packages (from pmdarima) (58.0.4)
# Requirement already satisfied: numpy>=1.19.3 in c:\users\jiexi\anaconda3\lib\site-packages (from pmdarima) (1.20.3)
# Requirement already satisfied: scikit-learn>=0.22 in c:\users\jiexi\anaconda3\lib\site-packages (from pmdarima) (0.24.2)
# Requirement already satisfied: joblib>=0.11 in c:\users\jiexi\anaconda3\lib\site-packages (from pmdarima) (1.1.0)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\jiexi\anaconda3\lib\site-packages (from pmdarima) (1.7.1)
# Requirement already satisfied: urllib3 in c:\users\jiexi\anaconda3\lib\site-packages (from pmdarima) (1.26.7)
# Requirement already satisfied: pytz>=2017.3 in c:\users\jiexi\anaconda3\lib\site-packages (from pandas>=0.19->pmdarima) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\jiexi\anaconda3\lib\site-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\jiexi\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas>=0.19->pmdarima) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\jiexi\anaconda3\lib\site-packages (from scikit-learn>=0.22->pmdarima) (2.2.0)
# Requirement already satisfied: patsy>=0.5 in c:\users\jiexi\anaconda3\lib\site-packages (from statsmodels!=0.12.0,>=0.11->pmdarima) (0.5.2)
# Requirement already satisfied: missingno in c:\users\jiexi\anaconda3\lib\site-packages (0.5.1)
# Requirement already satisfied: numpy in c:\users\jiexi\anaconda3\lib\site-packages (from missingno) (1.20.3)
# Requirement already satisfied: scipy in c:\users\jiexi\anaconda3\lib\site-packages (from missingno) (1.7.1)
# Requirement already satisfied: matplotlib in c:\users\jiexi\anaconda3\lib\site-packages (from missingno) (3.4.3)
# Requirement already satisfied: seaborn in c:\users\jiexi\anaconda3\lib\site-packages (from missingno) (0.11.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\jiexi\anaconda3\lib\site-packages (from matplotlib->missingno) (0.10.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\jiexi\anaconda3\lib\site-packages (from matplotlib->missingno) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\jiexi\anaconda3\lib\site-packages (from matplotlib->missingno) (1.3.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\jiexi\anaconda3\lib\site-packages (from matplotlib->missingno) (3.0.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\jiexi\anaconda3\lib\site-packages (from matplotlib->missingno) (8.4.0)
# Requirement already satisfied: six in c:\users\jiexi\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib->missingno) (1.16.0)
# Requirement already satisfied: pandas>=0.23 in c:\users\jiexi\anaconda3\lib\site-packages (from seaborn->missingno) (1.3.4)
# Requirement already satisfied: pytz>=2017.3 in c:\users\jiexi\anaconda3\lib\site-packages (from pandas>=0.23->seaborn->missingno) (2021.3)
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>

# %%
os.chdir("../assignment")
train = pd.read_csv("train_data.csv")
train.head()
# Out:
#    rumination  grazing  resting  mob_median_grazing  mob_std_grazing  \
# 0        12.0      0.0     58.0                 0.0              NaN
# 1        34.0      1.0     41.0                 2.0              4.0
# 2        49.0      0.0     49.0                 0.0              NaN
# 3        78.0      0.0     81.0                 0.0              NaN
# 4         9.0      0.0     51.0                 2.0              5.0
#
#    mob_median_resting  mob_std_resting  mob_median_rumination  \
# 0                58.0              NaN                   12.0
# 1                46.0              6.0                   26.0
# 2                49.0              NaN                   49.0
# 3                81.0              NaN                   78.0
# 4                42.0              7.0                   26.0
#
#    mob_std_rumination              utc_timestamp  ... pitch_std  \
# 0                 NaN  2022-08-11 04:00:00+00:00  ...       0.0
# 1                 8.0  2022-08-04 14:00:00+00:00  ...       3.0
# 2                 NaN  2022-08-06 16:00:00+00:00  ...       1.0
# 3                 NaN  2022-08-08 06:00:00+00:00  ...       0.0
# 4                 8.0  2022-08-04 12:00:00+00:00  ...       2.0
#
#    farm_average_odba_average  farm_average_odba_std  \
# 0                     1403.0                 1451.0
# 1                      599.0                  578.0
# 2                      446.0                  367.0
# 3                      883.0                  833.0
# 4                      765.0                  743.0
#
#    farm_average_pitch_average  farm_average_pitch_std  \
# 0                       -11.0                    11.0
# 1                         1.0                     6.0
# 2                         1.0                     5.0
# 3                         0.0                     7.0
# 4                        -1.0                     7.0
#
#    farm_average_roll_average  farm_average_roll_std  sickness_type  \
# 0                    12660.0                 5230.0       DOWN_COW
# 1                    10623.0                 4189.0       DOWN_COW
# 2                    10620.0                 3060.0       DOWN_COW
# 3                    10228.0                 4283.0       DOWN_COW
# 4                    11033.0                 4162.0       DOWN_COW
#
#    hours_since_sickness                               farm_id
# 0                 117.0  6d60ee09-e8ce-451b-9b31-06afa9c52140
# 1                 -41.0  6d60ee09-e8ce-451b-9b31-06afa9c52140
# 2                   9.0  6d60ee09-e8ce-451b-9b31-06afa9c52140
# 3                  47.0  6d60ee09-e8ce-451b-9b31-06afa9c52140
# 4                 -43.0  6d60ee09-e8ce-451b-9b31-06afa9c52140
#
# [5 rows x 29 columns]

# %%
#print("Current working directory:", os.getcwd())
os.chdir("../assignment")
train = pd.read_csv("train_data.csv")
train.head()
# Out:
#    rumination  grazing  resting  mob_median_grazing  mob_std_grazing  \
# 0         0.0     71.0      0.0                24.0              8.0
# 1        54.0      2.0     47.0                 0.0              6.0
# 2        60.0      0.0     50.0                 0.0              2.0
# 3        21.0      1.0     51.0                 1.0              7.0
# 4        41.0     15.0     32.0                 1.0              9.0
#
#    mob_median_resting  mob_std_resting  mob_median_rumination  \
# 0                26.0              6.0                   34.0
# 1                46.0              6.0                   49.0
# 2                50.0              2.0                   36.0
# 3                49.0              7.0                   44.0
# 4                46.0             10.0                   32.0
#
#    mob_std_rumination              utc_timestamp  ... roll_std  pitch_average  \
# 0                 9.0  2022-12-02 08:00:00+00:00  ...   6513.0          -33.0
# 1                10.0  2022-12-02 09:00:00+00:00  ...   2246.0           16.0
# 2                10.0  2022-12-02 10:00:00+00:00  ...   1930.0           16.0
# 3                10.0  2022-12-02 11:00:00+00:00  ...   3173.0           13.0
# 4                11.0  2022-12-02 12:00:00+00:00  ...   3757.0           -3.0
#
#    pitch_std  farm_average_odba_average  farm_average_odba_std  \
# 0       10.0                     1840.0                 1403.0
# 1        4.0                      765.0                  562.0
# 2        3.0                      579.0                  417.0
# 3        5.0                     1043.0                  727.0
# 4        6.0                     1080.0                  748.0
#
#    farm_average_pitch_average  farm_average_pitch_std  \
# 0                       -16.0                     6.0
# 1                        -1.0                     4.0
# 2                        -2.0                     4.0
# 3                        -9.0                     4.0
# 4                        -9.0                     4.0
#
#    farm_average_roll_average  farm_average_roll_std  \
# 0                    11920.0                 4890.0
# 1                     7981.0                 3291.0
# 2                     9889.0                 3541.0
# 3                     9762.0                 3635.0
# 4                     9357.0                 3337.0
#
#                                 farm_id
# 0  36a981ca-0efa-4892-bf07-74bd0210a528
# 1  36a981ca-0efa-4892-bf07-74bd0210a528
# 2  36a981ca-0efa-4892-bf07-74bd0210a528
# 3  36a981ca-0efa-4892-bf07-74bd0210a528
# 4  36a981ca-0efa-4892-bf07-74bd0210a528
#
# [5 rows x 27 columns]

# %%
# Check the number of rows of the dataset
print("The number of rows:", len(test))
# Out:
# The number of rows: 783494

# %%
# Display the column names (variables) in the header
print(test.columns)
# Out:
# Index(['rumination', 'grazing', 'resting', 'mob_median_grazing',
#        'mob_std_grazing', 'mob_median_resting', 'mob_std_resting',
#        'mob_median_rumination', 'mob_std_rumination', 'utc_timestamp',
#        'cattle_id', 'farm_average_rumination', 'farm_average_grazing',
#        'farm_average_resting', 'odba_average', 'odba_std', 'roll_average',
#        'roll_std', 'pitch_average', 'pitch_std', 'farm_average_odba_average',
#        'farm_average_odba_std', 'farm_average_pitch_average',
#        'farm_average_pitch_std', 'farm_average_roll_average',
#        'farm_average_roll_std', 'farm_id'],
#       dtype='object')

# %%
# Select rows with the first two cattle ids
specified_cattle_ids = ["092741cd-adea-4d43-9419-06da335e9d46", "1e5849d3-865f-4f11-bc19-b2ba6948ce86"]
selected_rows = test[test['cattle_id'].isin(specified_cattle_ids)]
# Add a new index column to the selected_rows DataFrame
selected_rows = selected_rows.reset_index(drop=False)
# Rename the new index column
selected_rows = selected_rows.rename(columns={'index': 'new_index'})
# Check the number of rows of the dataset
print("The number of rows:", len(selected_rows))
# Out:
# The number of rows: 4798

# %%
# Save the selected rows as a new CSV file
selected_rows.to_csv('../assignment/selected_rows.csv')

# %%
# Read in the data of the first two cows
os.chdir("../assignment")
select = pd.read_csv("selected_rows.csv")
select.head()
# Out:
#    Unnamed: 0  new_index  rumination  grazing  resting  mob_median_grazing  \
# 0           0          0         0.0     71.0      0.0                24.0
# 1           1          1        54.0      2.0     47.0                 0.0
# 2           2          2        60.0      0.0     50.0                 0.0
# 3           3          3        21.0      1.0     51.0                 1.0
# 4           4          4        41.0     15.0     32.0                 1.0
#
#    mob_std_grazing  mob_median_resting  mob_std_resting  \
# 0              8.0                26.0              6.0
# 1              6.0                46.0              6.0
# 2              2.0                50.0              2.0
# 3              7.0                49.0              7.0
# 4              9.0                46.0             10.0
#
#    mob_median_rumination  ...  roll_std pitch_average pitch_std  \
# 0                   34.0  ...    6513.0         -33.0      10.0
# 1                   49.0  ...    2246.0          16.0       4.0
# 2                   36.0  ...    1930.0          16.0       3.0
# 3                   44.0  ...    3173.0          13.0       5.0
# 4                   32.0  ...    3757.0          -3.0       6.0
#
#    farm_average_odba_average  farm_average_odba_std  \
# 0                     1840.0                 1403.0
# 1                      765.0                  562.0
# 2                      579.0                  417.0
# 3                     1043.0                  727.0
# 4                     1080.0                  748.0
#
#    farm_average_pitch_average  farm_average_pitch_std  \
# 0                       -16.0                     6.0
# 1                        -1.0                     4.0
# 2                        -2.0                     4.0
# 3                        -9.0                     4.0
# 4                        -9.0                     4.0
#
#    farm_average_roll_average  farm_average_roll_std  \
# 0                    11920.0                 4890.0
# 1                     7981.0                 3291.0
# 2                     9889.0                 3541.0
# 3                     9762.0                 3635.0
# 4                     9357.0                 3337.0
#
#                                 farm_id
# 0  36a981ca-0efa-4892-bf07-74bd0210a528
# 1  36a981ca-0efa-4892-bf07-74bd0210a528
# 2  36a981ca-0efa-4892-bf07-74bd0210a528
# 3  36a981ca-0efa-4892-bf07-74bd0210a528
# 4  36a981ca-0efa-4892-bf07-74bd0210a528
#
# [5 rows x 29 columns]
